# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importing FHFA House Price Index Data

# %%
MD_data = pd.read_csv('/Users/nyahamlet/Documents/Business/Certs/VT Data Analytics Bootcamp/Capstone Project/Data/FHFA Home Price Index/Home Price Index_All Transactions_county.v2.csv')

# %%
MD_data.head()
# Out:
#   State   County  FIPS code  Year  Annual Change (%)     HPI  \
# 0    AL  Autauga       1001  1986                NaN  100.00
# 1    AL  Autauga       1001  1987              -2.19   97.81
# 2    AL  Autauga       1001  1988               3.68  101.42
# 3    AL  Autauga       1001  1989               4.32  105.80
# 4    AL  Autauga       1001  1990              -0.50  105.27
#
#    HPI with 1990 base  HPI with 2000 base
# 0               94.99               70.29
# 1               92.91               68.75
# 2               96.34               71.29
# 3              100.50               74.37
# 4              100.00               74.00

# %% [markdown]
# Filling null values w/ Median

# %%
MD_data['HPI with 1990 base'] = MD_data['HPI with 1990 base'].fillna(MD_data['HPI with 1990 base'].median())

# %%
print(MD_data)
# Out:
#       State   County  FIPS code  Year  Annual Change (%)     HPI  \
# 0        AL  Autauga       1001  1986                NaN  100.00
# 1        AL  Autauga       1001  1987              -2.19   97.81
# 2        AL  Autauga       1001  1988               3.68  101.42
# 3        AL  Autauga       1001  1989               4.32  105.80
# 4        AL  Autauga       1001  1990              -0.50  105.27
# ...     ...      ...        ...   ...                ...     ...
# 94530    WY   Weston      56045  2017               1.70  199.85
# 94531    WY   Weston      56045  2018              -1.29  197.27
# 94532    WY   Weston      56045  2019               8.83  214.69
# 94533    WY   Weston      56045  2020               4.15  223.61
# 94534    WY   Weston      56045  2021               7.06  239.39
#
#        HPI with 1990 base  HPI with 2000 base
# 0                   94.99               70.29
# 1                   92.91               68.75
# ...

# %%
MD_data['HPI'] = MD_data['HPI'].fillna(MD_data['HPI'].median())

# %%
MD_data['Annual Change (%)'] = MD_data['Annual Change (%)'].fillna(MD_data['Annual Change (%)'].median())

# %%
MD_data['HPI with 2000 base'] = MD_data['HPI with 2000 base'].fillna(MD_data['HPI with 2000 base'].median())

# %%
print(MD_data)
# Out:
#       State   County  FIPS code  Year  Annual Change (%)     HPI  \
# 0        AL  Autauga       1001  1986               3.34  100.00
# 1        AL  Autauga       1001  1987              -2.19   97.81
# 2        AL  Autauga       1001  1988               3.68  101.42
# 3        AL  Autauga       1001  1989               4.32  105.80
# 4        AL  Autauga       1001  1990              -0.50  105.27
# ...     ...      ...        ...   ...                ...     ...
# 94530    WY   Weston      56045  2017               1.70  199.85
# 94531    WY   Weston      56045  2018              -1.29  197.27
# 94532    WY   Weston      56045  2019               8.83  214.69
# 94533    WY   Weston      56045  2020               4.15  223.61
# 94534    WY   Weston      56045  2021               7.06  239.39
#
#        HPI with 1990 base  HPI with 2000 base
# 0                   94.99               70.29
# 1                   92.91               68.75
# ...

# %% [markdown]
# Pulling Stats on FHFA House Price Index Data

# %%
print(MD_data.describe())
# Out:
#           FIPS code          Year  Annual Change (%)           HPI  \
# count  94535.000000  94535.000000       94535.000000  94535.000000
# mean   30144.983202   2003.062146           3.617431    227.676673
# std    15169.545337     11.850880           5.827259    152.233612
# min     1001.000000   1975.000000         -45.250000     45.010000
# 25%    18105.000000   1995.000000           0.700000    135.630000
# 50%    29093.000000   2004.000000           3.340000    182.345000
# 75%    42123.000000   2013.000000           6.140000    261.505000
# max    56045.000000   2021.000000          75.840000   2116.550000
#
#        HPI with 1990 base  HPI with 2000 base
# count        94535.000000        94535.000000
# mean           150.556683          110.616812
# std             53.732078           39.932217
# min             18.110000           10.890000
# 25%            121.800000           83.540000
# 50%            146.850000          109.450000
# ...

# %% [markdown]
# Exporting Updated Version of FHFA House Price Index Data

# %%
MD_data.to_excel (r'/Users/nyahamlet/Documents/Business/Certs/VT Data Analytics Bootcamp/Capstone Project/Data/FHFA Home Price Index/Home Price Index_All Transactions_county.v4.xlsx', index = False, header=True)

# %% [markdown]
# Importing MD County Demographic Data

# %%
MD_Demo = pd.read_csv('/Users/nyahamlet/Documents/Business/Certs/VT Data Analytics Bootcamp/Capstone Project/Data/MD County Demographics/County_Demographics_2016-2020.csv')

# %%
MD_Demo.head()
# Out:
#            GEO_ID                           NAME  DP05_0001E DP05_0001M  \
# 0  0500000US24001      Allegany County, Maryland       71002      *****
# 1  0500000US24003  Anne Arundel County, Maryland      575421      *****
# 2  0500000US24005     Baltimore County, Maryland      828193      *****
# 3  0500000US24009       Calvert County, Maryland       92094      *****
# 4  0500000US24011      Caroline County, Maryland       33260      *****
#
#    DP05_0001PE DP05_0001PM  DP05_0002E  DP05_0002M  DP05_0002PE  DP05_0002PM  \
# 0        71002         (X)       37329         195         52.6          0.3
# 1       575421         (X)      284682         139         49.5          0.1
# 2       828193         (X)      392167          89         47.4          0.1
# 3        92094         (X)       45651         172         49.6          0.2
# 4        33260         (X)       16312         109         49.0          0.3
#
# ...

# %% [markdown]
# Renaming Chosen Columns

# %%
MD_Demo = MD_Demo.rename(columns={'DP05_0037E': 'White', 'DP05_0038E': 'Black', 'DP05_0039E':'American_Indian_Alaska_Native', 'DP05_0040E': 'American_Indian_Alaska_Native_Cherokee', 'DP05_0041E': 'American_Indian_Alaska_Native_Chippewa', 'DP05_0042E': 'American_Indian_Alaska_Native_Navajo', 'DP05_0043E': 'American_Indian_Alaska_Native_Sioux', 'DP05_0044E': 'Asian', 'DP05_0045E': 'Asian_Indian', 'DP05_0046E': 'Asian_Chinese', 'DP05_0047E': 'Asian_Filipino', 'DP05_0048E': 'Asian_Japanese', 'DP05_0049E': 'Asian_Korean', 'DP05_0050E': 'Asian_Vietnamese', 'DP05_0051E': 'Other_Asian', 'DP05_0052E': 'Native_Hawaiian_Other_Pac_Islander', 'DP05_0053E': 'Native_Hawaiian_Other_Pac_Islander_Native_Hawaiian', 'DP05_0054E': 'Native_Hawaiian_Other_Pac_Islander_Chamorro', 'DP05_0055E': 'Native_Hawaiian_Other_Pac_Islander_Samoan', 'DP05_0056E': 'Other_Pacific_Islander', 'DP05_0057E': 'Some_other_race', 'DP05_0058E': 'Two_or_more_races'})

# %%
MD_Demo.head()
# Out:
#            GEO_ID                           NAME  DP05_0001E DP05_0001M  \
# 0  0500000US24001      Allegany County, Maryland       71002      *****
# 1  0500000US24003  Anne Arundel County, Maryland      575421      *****
# 2  0500000US24005     Baltimore County, Maryland      828193      *****
# 3  0500000US24009       Calvert County, Maryland       92094      *****
# 4  0500000US24011      Caroline County, Maryland       33260      *****
#
#    DP05_0001PE DP05_0001PM  DP05_0002E  DP05_0002M  DP05_0002PE  DP05_0002PM  \
# 0        71002         (X)       37329         195         52.6          0.3
# 1       575421         (X)      284682         139         49.5          0.1
# 2       828193         (X)      392167          89         47.4          0.1
# 3        92094         (X)       45651         172         49.6          0.2
# 4        33260         (X)       16312         109         49.0          0.3
#
# ...

# %% [markdown]
# Renaming County/State Column for Consistency Purposes

# %%
MD_Demo = MD_Demo.rename(columns={'NAME':'County'})

# %%
MD_Demo.head()
# Out:
#            GEO_ID                         County  DP05_0001E DP05_0001M  \
# 0  0500000US24001      Allegany County, Maryland       71002      *****
# 1  0500000US24003  Anne Arundel County, Maryland      575421      *****
# 2  0500000US24005     Baltimore County, Maryland      828193      *****
# 3  0500000US24009       Calvert County, Maryland       92094      *****
# 4  0500000US24011      Caroline County, Maryland       33260      *****
#
#    DP05_0001PE DP05_0001PM  DP05_0002E  DP05_0002M  DP05_0002PE  DP05_0002PM  \
# 0        71002         (X)       37329         195         52.6          0.3
# 1       575421         (X)      284682         139         49.5          0.1
# 2       828193         (X)      392167          89         47.4          0.1
# 3        92094         (X)       45651         172         49.6          0.2
# 4        33260         (X)       16312         109         49.0          0.3
#
# ...

# %% [markdown]
# Creating a DataFrame That Only Contains the Renamed Columns

# %%
MD_Demo2 = MD_Demo[["County", "White", "Black", "American_Indian_Alaska_Native", "American_Indian_Alaska_Native_Cherokee", "American_Indian_Alaska_Native_Chippewa", "American_Indian_Alaska_Native_Navajo", "American_Indian_Alaska_Native_Sioux", "Asian", "Asian_Indian", "Asian_Chinese", "Asian_Filipino", "Asian_Japanese", "Asian_Korean", "Asian_Vietnamese", "Other_Asian", "Native_Hawaiian_Other_Pac_Islander", "Native_Hawaiian_Other_Pac_Islander_Native_Hawaiian", "Native_Hawaiian_Other_Pac_Islander_Chamorro", "Native_Hawaiian_Other_Pac_Islander_Samoan", "Other_Pacific_Islander", "Some_other_race", "Two_or_more_races"]]

# %%
MD_Demo2.head()
# Out:
#                           County   White   Black  \
# 0      Allegany County, Maryland   62420    5954
# 1  Anne Arundel County, Maryland  408297   96112
# 2     Baltimore County, Maryland  487523  243098
# 3       Calvert County, Maryland   73985   11456
# 4      Caroline County, Maryland   26076    4589
#
#    American_Indian_Alaska_Native  American_Indian_Alaska_Native_Cherokee  \
# 0                            117                                      18
# 1                           1218                                     135
# 2                           2111                                     436
# 3                            155                                       0
# 4                             94                                      25
#
#    American_Indian_Alaska_Native_Chippewa  \
# 0                                       2
# 1                                      15
# 2                                       0
# 3                                       0
# ...

# %% [markdown]
# Separating County from State

# %%
MD_Demo2[['County','State']]=MD_Demo2.County.str.split(',',expand=True)
print(MD_Demo2)
# Out:
#                     County   White   Black  American_Indian_Alaska_Native  \
# 0          Allegany County   62420    5954                            117
# 1      Anne Arundel County  408297   96112                           1218
# 2         Baltimore County  487523  243098                           2111
# 3           Calvert County   73985   11456                            155
# 4          Caroline County   26076    4589                             94
# 5           Carroll County  152180    6088                            437
# 6             Cecil County   89478    7032                             81
# 7           Charles County   67215   76590                           1028
# 8        Dorchester County   20777    8216                             12
# 9         Frederick County  200484   25253                            568
# 10          Garrett County   28162     348                             50
# 11          Harford County  197023   35208                            380
# ...

# %%
MD_Demo2.head()
# Out:
#                 County   White   Black  American_Indian_Alaska_Native  \
# 0      Allegany County   62420    5954                            117
# 1  Anne Arundel County  408297   96112                           1218
# 2     Baltimore County  487523  243098                           2111
# 3       Calvert County   73985   11456                            155
# 4      Caroline County   26076    4589                             94
#
#    American_Indian_Alaska_Native_Cherokee  \
# 0                                      18
# 1                                     135
# 2                                     436
# 3                                       0
# 4                                      25
#
#    American_Indian_Alaska_Native_Chippewa  \
# 0                                       2
# 1                                      15
# 2                                       0
# 3                                       0
# 4                                       0
#
# ...

# %% [markdown]
# Reordering Columns

# %%
MD_Demo3 = MD_Demo2[["State", "County", "White", "Black", "American_Indian_Alaska_Native", "American_Indian_Alaska_Native_Cherokee", "American_Indian_Alaska_Native_Chippewa", "American_Indian_Alaska_Native_Navajo", "American_Indian_Alaska_Native_Sioux", "Asian", "Asian_Indian", "Asian_Chinese", "Asian_Filipino", "Asian_Japanese", "Asian_Korean", "Asian_Vietnamese", "Other_Asian", "Native_Hawaiian_Other_Pac_Islander", "Native_Hawaiian_Other_Pac_Islander_Native_Hawaiian", "Native_Hawaiian_Other_Pac_Islander_Chamorro", "Native_Hawaiian_Other_Pac_Islander_Samoan", "Other_Pacific_Islander", "Some_other_race", "Two_or_more_races"]]

# %%
MD_Demo3.head()
# Out:
#        State               County   White   Black  \
# 0   Maryland      Allegany County   62420    5954
# 1   Maryland  Anne Arundel County  408297   96112
# 2   Maryland     Baltimore County  487523  243098
# 3   Maryland       Calvert County   73985   11456
# 4   Maryland      Caroline County   26076    4589
#
#    American_Indian_Alaska_Native  American_Indian_Alaska_Native_Cherokee  \
# 0                            117                                      18
# 1                           1218                                     135
# 2                           2111                                     436
# 3                            155                                       0
# 4                             94                                      25
#
#    American_Indian_Alaska_Native_Chippewa  \
# 0                                       2
# 1                                      15
# 2                                       0
# 3                                       0
# ...

# %% [markdown]
# Exporting Updated MD County Demographic Data

# %%
MD_Demo3.to_excel (r'/Users/nyahamlet/Documents/Business/Certs/VT Data Analytics Bootcamp/Capstone Project/Data/MD County Demographics/County_Demographics_2016-2020.v3.xlsx', index = False, header=True)

# %%
MD_data2 = pd.read_csv('/Users/nyahamlet/Documents/Business/Certs/VT Data Analytics Bootcamp/Capstone Project/Final/MD_Housing_Data.csv')

# %%
MD_data2.head()
# Out:
#       State           County  Year  Annual_Change     HPI  White  Black  \
# 0  Maryland  Allegany County  2015           0.72  234.89  62420   5954
# 1  Maryland  Allegany County  2016          -0.29  234.22  62420   5954
# 2  Maryland  Allegany County  2017           4.52  244.79  62420   5954
# 3  Maryland  Allegany County  2018          -1.57  240.95  62420   5954
# 4  Maryland  Allegany County  2019           4.14  250.92  62420   5954
#
#    American_Indian_Alaska_Native  American_Indian_Alaska_Native_Cherokee  \
# 0                            117                                      18
# 1                            117                                      18
# 2                            117                                      18
# 3                            117                                      18
# 4                            117                                      18
#
#    American_Indian_Alaska_Native_Chippewa  ...  Asian_Japanese  Asian_Korean  \
# ...

# %% [markdown]
# Changing Year to Date Format

# %%
import datetime

# %%
MD_data2['Year'] = pd.to_datetime(MD_data2['Year'], format= "%Y")

# %%
MD_data2.dtypes
# Out:
# State                                                         object
# County                                                        object
# Year                                                  datetime64[ns]
# Annual_Change                                                float64
# HPI                                                          float64
# White                                                          int64
# Black                                                          int64
# American_Indian_Alaska_Native                                  int64
# American_Indian_Alaska_Native_Cherokee                         int64
# American_Indian_Alaska_Native_Chippewa                         int64
# American_Indian_Alaska_Native_Navajo                           int64
# American_Indian_Alaska_Native_Sioux                            int64
# Asian                                                          int64
# Asian_Indian                                                   int64
# ...

# %% [markdown]
# Export MD Housing Data (Final)

# %%
MD_data2.to_excel (r'/Users/nyahamlet/Documents/Business/Certs/VT Data Analytics Bootcamp/Capstone Project/MD_Housing_Data.xlsx', index = False, header=True)
